# %%
import numpy as np

# %%
import pandas as pd

# %%
import pyarrow as py

# %%
df = pd.read_csv('./Downloads/DoorDashSales2023.csv')
df2 = pd.read_csv('./Downloads/DoorDashSalesJanToFeb2024.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Granularity                              12 non-null     object
#  1   Start Date                               12 non-null     object
#  2   End Date                                 12 non-null     object
#  3   Store Name                               12 non-null     object
#  4   Store ID                                 12 non-null     int64
#  5   Business ID                              12 non-null     int64
#  6   Merchant Supplied ID                     12 non-null     object
#  7   Gross Sales                              12 non-null     float64
#  8   Total Orders Including Cancelled Orders  12 non-null     int64
#  9   Total Delivered or Picked Up Orders      12 non-null     int64
# ...

# %%
df.drop(['Store Name', 'Store ID', 'Store ID', 'Merchant Supplied ID', 'Business ID', 'Currency'], axis=1)
# Out:
#          Granularity  Start Date    End Date  Gross Sales  \
# 0   Month of 2023-12  2023-12-01  2023-12-31      3385.73
# 1   Month of 2023-11  2023-11-01  2023-11-30      3158.94
# 2   Month of 2023-10  2023-10-01  2023-10-31      1811.90
# 3   Month of 2023-09  2023-09-01  2023-09-30      1804.08
# 4   Month of 2023-08  2023-08-01  2023-08-31      2359.74
# 5   Month of 2023-07  2023-07-01  2023-07-31      2828.29
# 6   Month of 2023-06  2023-06-01  2023-06-30      2378.74
# 7   Month of 2023-05  2023-05-01  2023-05-31      3023.63
# 8   Month of 2023-04  2023-04-01  2023-04-30      2097.42
# 9   Month of 2023-03  2023-03-01  2023-03-31      2654.20
# 10  Month of 2023-02  2023-02-01  2023-02-28      2277.37
# 11  Month of 2023-01  2023-01-01  2023-01-31      3668.96
#
#     Total Orders Including Cancelled Orders  \
# 0                                       114
# 1                                       109
# 2                                        61
# ...

# %%
import matplotlib.pyplot as plt
line1 = plt.plot(df.index, df["Gross Sales"], color='Indigo', label='2023')
line2 = plt.plot(df2.index, df2["Gross Sales"], color='Orange', label='2024')
plt.title("Door Dash Sales by Month")
plt.xlabel('Months')
plt.ylabel('Gross Sales')
leg = plt.legend(loc='lower right', frameon=False);
plt.grid()
plt.show()
